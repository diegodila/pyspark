# %%
import psycopg2
import pandas as pd
from pyspark.sql import SparkSession
from sqlalchemy import create_engine

# %%
appName = "PySpark PostgreSQL Example - via psycopg2"
master = "local"
spark = SparkSession.builder.master(master).appName(appName).getOrCreate()

# %%
url = "postgresql+psycopg2://postgres:dwut6PLAF%2Alik%40meb@postgresql.cadastra.com/fiserv?client_encoding=utf8"

# %%
engine = create_engine(url)
pdf = pd.read_sql('SELECT "Name", regua, nome_dash, "_airbyte_ab_id", "_airbyte_emitted_at", "_airbyte_normalized_at", "_airbyte_depara_bin_hashid" FROM raw.depara_bin;', engine)

# %%
pdf
# Out:
#                                           Name           regua  \
# 0                        automation_boasvindas      ONBOARDING
# 1                automation_chegada-maquininha      ONBOARDING
# 2                     automation_gestao-vendas      ONBOARDING
# 3                          automation_ativacao      ONBOARDING
# 4              automation_confirmacao-cadastro      ONBOARDING
# 5                     automation_inativando-d2      ONBOARDING
# 6                    automation_inativando-d10      ONBOARDING
# 7                      automation_inativos-d10      ONBOARDING
# 8                    automation_inativando-d30      ONBOARDING
# 9                    automation_inativando-d65  INFORMACIONAIS
# 10                      automation_antecipacao  INFORMACIONAIS
# 11                  automation_antecipacao-d15  INFORMACIONAIS
# 12      automation_canais-antecipacao-mdr-flex  INFORMACIONAIS
# 13  automation_beneficios-antecipacao-mdr-flex  INFORMACIONAIS
# ...

# %%
# Convert Pandas dataframe to spark DataFrame
df = spark.createDataFrame(pdf)
print(df.schema)
df.show()
# Out:
# StructType(List(StructField(Name,StringType,true),StructField(regua,StringType,true),StructField(nome_dash,StringType,true),StructField(_airbyte_ab_id,StringType,true),StructField(_airbyte_emitted_at,TimestampType,true),StructField(_airbyte_normalized_at,TimestampType,true),StructField(_airbyte_depara_bin_hashid,StringType,true)))
# +--------------------+--------------+--------------------+--------------------+-------------------+----------------------+--------------------------+
# |                Name|         regua|           nome_dash|      _airbyte_ab_id|_airbyte_emitted_at|_airbyte_normalized_at|_airbyte_depara_bin_hashid|
# +--------------------+--------------+--------------------+--------------------+-------------------+----------------------+--------------------------+
# |automation_boasvi...|    ONBOARDING|BOAS VINDAS SEM T...|0110df79-e960-489...|2022-04-15 07:24:45|  2022-04-15 07:24:...|      3fc78f529ac65ea0e...|
# ...
